# %%
import re

# %%
def parsefile(fname):
    
    mydictionary = {
    "1. CLB Logic":{0: {"Site type": "", "used": 0, "fixed": 0, "available": 0, "util%": 0.00} 
                   },
    "2. BLOCKRAM":{0: {"Site type": "", "used": 0, "fixed": 0, "available": 0, "util%": 0.00} 
                   },
    "3. ARITHMETIC":{0: {"Site type": "", "used": 0, "fixed": 0, "available": 0, "util%": 0.00} 
                   },
    "4. I/O":{0: {"Site type": "", "used": 0, "fixed": 0, "available": 0, "util%": 0.00} 
                   },
    "5. CLOCK":{0: {"Site type": "0", "used": 0, "fixed": 0, "available": 0, "util%": 0.00}
                   },
    "6. ADVANCED":{0: {"Site type": "", "used": 0, "fixed": 0, "available": 0, "util%": 0.00} 
                   },
    "7. CONFIGURATION":{0: {"Site type": "", "used": 0, "fixed": 0, "available": 0, "util%": 0.00}
                   },
    "8. Primitives":{0: {"Ref Name": "", "used": 0, "Functional Category": ""} 
                   },
    "11. SLR Connectivity":{0: {"SLL type": "", "used": 0, "fixed": 0, "available": 0, "util%": 0.00} 
                   },
    "12. SLR Connectivity Matrix":{0: {"From\to": "", "SLR2": 0, "SLR1": 0, "SLR0": 0} 
                   },
    "13. SLR CLB Logic and Dedicated Block Utilization":{0: {"Site type": "", "SLR0": 0, "SLR1": 0, "SLR2": 0, "SLR0%": 0.00, "SLR1%": 0.00, "SLR2%": 0.00}
                   },
    "14. SLR IO Utilization":{0: {"SLR Index": "", "used IOBs": 0, "(%)IOBs": 0.00, "used ipads": 0, "(%)IPADs": 0.00, "Used OPADs": 0, "(%)OPADs": 0.00, "GTs": 0}
                   }
    }
    filepath = 'n32R8.rpt'
    with open(filepath) as fp:
        line = fp.readline()
        cnt = 29
        for x in range(0, 30):
            line = fp.readline()
        while line:

            if re.search("1. CLB Logic",line):
                
                for x in range(0 , 6):
                    line = fp.readline()
                for g in range(0,12):
                    
                    temp = line
                    temp = temp.split("|")
                    site_type = temp[1].strip()
                    used = temp[2].strip()
                    fixed = temp[3].strip()
                    available = temp[4].strip()
                    util = temp[5].strip()
                    if used != '':
                        int(used)
                    if fixed != '':
                        int(fixed)
                    if available != '':
                        int(available)
                    if util != '':
                        float(util)
                    mydictionary["1. CLB Logic"][g] = {}
                    mydictionary["1. CLB Logic"][g]["Site type"] = site_type
                    mydictionary["1. CLB Logic"][g]["used"] = used
                    mydictionary["1. CLB Logic"][g]["fixed"] = fixed
                    mydictionary["1. CLB Logic"][g]["available"] = available
                    mydictionary["1. CLB Logic"][g]["util"] = util
                    line = fp.readline()
                
            elif re.search("2. BLOCKRAM", line):
                
                for x in range(0 , 6):
                    line = fp.readline()
                for g in range(0,4):
                    temp = line
                    temp = temp.split("|")
                    site_type = temp[1].strip()
                    used = temp[2].strip()
                    fixed = temp[3].strip()
                    available = temp[4].strip()
                    util = temp[5].strip()
                    if used != '':
                        int(used)
                    if fixed != '':
                        int(fixed)
                    if available != '':
                        int(available)
                    if util != '':
                        float(util)
                    mydictionary["2. BLOCKRAM"][g] = {}
                    mydictionary["2. BLOCKRAM"][g]["Site type"] = site_type
                    mydictionary["2. BLOCKRAM"][g]["used"] = used
                    mydictionary["2. BLOCKRAM"][g]["fixed"] = fixed
                    mydictionary["2. BLOCKRAM"][g]["available"] = available
                    mydictionary["2. BLOCKRAM"][g]["util"] = util
                    line = fp.readline()
            elif re.search("3. ARITHMETIC", line):

                for x in range(0 , 6):
                    line = fp.readline()
                for g in range(0,1):
                    temp = line
                    temp = temp.split("|")
                    site_type = temp[1].strip()
                    used = temp[2].strip()
                    fixed = temp[3].strip()
                    available = temp[4].strip()
                    util = temp[5].strip()
                    if used != '':
                        int(used)
                    if fixed != '':
                        int(fixed)
                    if available != '':
                        int(available)
                    if util != '':
                        float(util)
                    mydictionary["3. ARITHMETIC"][g] = {}
                    mydictionary["3. ARITHMETIC"][g]["Site type"] = site_type
                    mydictionary["3. ARITHMETIC"][g]["used"] = used
                    mydictionary["3. ARITHMETIC"][g]["fixed"] = fixed
                    mydictionary["3. ARITHMETIC"][g]["available"] = available
                    mydictionary["3. ARITHMETIC"][g]["util"] = util
                    line = fp.readline()
                    
            elif re.search("4. I/O", line):
                for x in range(0 , 6):
                    line = fp.readline()
                for g in range(0,1):
                    temp = line
                    temp = temp.split("|")
                    site_type = temp[1].strip()
                    used = temp[2].strip()
                    fixed = temp[3].strip()
                    available = temp[4].strip()
                    util = temp[5].strip()
                    if used != '':
                        int(used)
                    if fixed != '':
                        int(fixed)
                    if available != '':
                        int(available)
                    if util != '':
                        float(util)
                    mydictionary["4. I/O"][g] = {}
                    mydictionary["4. I/O"][g]["Site type"] = site_type
                    mydictionary["4. I/O"][g]["used"] = used
                    mydictionary["4. I/O"][g]["fixed"] = fixed
                    mydictionary["4. I/O"][g]["available"] = available
                    mydictionary["4. I/O"][g]["util"] = util
                    line = fp.readline()     
                
            elif re.search("5. CLOCK", line):
                
                for x in range(0 , 6):
                    line = fp.readline()
                for g in range(0,7):
                    temp = line
                    temp = temp.split("|")
                    site_type = temp[1].strip()
                    used = temp[2].strip()
                    fixed = temp[3].strip()
                    available = temp[4].strip()
                    util = temp[5].strip()
                    if used != '':
                        int(used)
                    if fixed != '':
                        int(fixed)
                    if available != '':
                        int(available)
                    if util != '':
                        float(util)
                    mydictionary["5. CLOCK"][g] = {}
                    mydictionary["5. CLOCK"][g]["Site type"] = site_type
                    mydictionary["5. CLOCK"][g]["used"] = used
                    mydictionary["5. CLOCK"][g]["fixed"] = fixed
                    mydictionary["5. CLOCK"][g]["available"] = available
                    mydictionary["5. CLOCK"][g]["util"] = util
                    line = fp.readline()
                

            elif re.search("6. ADVANCED", line):
                
                for x in range(0 , 6):
                    line = fp.readline()
                for g in range(0,12):
                    temp = line
                    temp = temp.split("|")
                    site_type = temp[1].strip()
                    used = temp[2].strip()
                    fixed = temp[3].strip()
                    available = temp[4].strip()
                    util = temp[5].strip()
                    if used != '':
                        int(used)
                    if fixed != '':
                        int(fixed)
                    if available != '':
                        int(available)
                    if util != '':
                        float(util)
                    mydictionary["6. ADVANCED"][g] = {}
                    mydictionary["6. ADVANCED"][g]["Site type"] = site_type
                    mydictionary["6. ADVANCED"][g]["used"] = used
                    mydictionary["6. ADVANCED"][g]["fixed"] = fixed
                    mydictionary["6. ADVANCED"][g]["available"] = available
                    mydictionary["6. ADVANCED"][g]["util"] = util
                    line = fp.readline()
                

            elif re.search("7. CONFIGURATION", line):
                
                for x in range(0 , 6):
                    line = fp.readline()
                for g in range(0,7):
                    temp = line
                    temp = temp.split("|")
                    site_type = temp[1].strip()
                    used = temp[2].strip()
                    fixed = temp[3].strip()
                    available = temp[4].strip()
                    util = temp[5].strip()
                    if used != '':
                        int(used)
                    if fixed != '':
                        int(fixed)
                    if available != '':
                        int(available)
                    if util != '':
                        float(util)
                    mydictionary["7. CONFIGURATION"][g] = {}
                    mydictionary["7. CONFIGURATION"][g]["Site type"] = site_type
                    mydictionary["7. CONFIGURATION"][g]["used"] = used
                    mydictionary["7. CONFIGURATION"][g]["fixed"] = fixed
                    mydictionary["7. CONFIGURATION"][g]["available"] = available
                    mydictionary["7. CONFIGURATION"][g]["util"] = util
                    line = fp.readline()
                

            elif re.search("8. Primitives", line):
                
                for x in range(0 , 6):
                    line = fp.readline()
                for g in range(0,7):
                    temp = line
                    temp = temp.split("|")
                    Refname = temp[1].strip()
                    used = temp[2].strip()
                    functional_cat = temp[3].strip()
                    int(used)
                    mydictionary["8. Primitives"][g] = {}
                    mydictionary["8. Primitives"][g]["used"] = used
                    mydictionary["8. Primitives"][g]["Functional Category"] = functional_cat
                    line = fp.readline()
                
            elif re.search("11. SLR Connectivity", line):
                
                for x in range(0 , 6):
                    line = fp.readline()
                for g in range(0,19):
                    temp = line
                    temp = temp.split("|")
                    site_type = temp[1].strip()
                    used = temp[2].strip()
                    fixed = temp[3].strip()
                    available = temp[4].strip()
                    util = temp[5].strip()
                    if used != '':
                        int(used)
                    if fixed != '':
                        int(fixed)
                    if available != '':
                        int(available)
                    if util != '':
                        float(util)
                    mydictionary["11. SLR Connectivity"][g] = {}
                    mydictionary["11. SLR Connectivity"][g]["Site type"] = site_type
                    mydictionary["11. SLR Connectivity"][g]["used"] = used
                    mydictionary["11. SLR Connectivity"][g]["fixed"] = fixed
                    mydictionary["11. SLR Connectivity"][g]["available"] = available
                    mydictionary["11. SLR Connectivity"][g]["util"] = util
                    if g == 17:
                        line = fp.readline()
                    line = fp.readline()
                
                
            elif re.search("12. SLR Connectivity Matrix", line):
                
                for x in range(0 , 6):
                    line = fp.readline()
                for g in range(0,3):
                    temp = line
                    temp = temp.split("|")
                    from_to = temp[1].strip()
                    slr2 = temp[2].strip()
                    slr1 = temp[3].strip()
                    slr0 = temp[4].strip()
                    if slr2 != '':
                        int(slr2)
                    if slr1 != '':
                        int(slr1)
                    if slr0 != '':
                        int(slr0)
                    mydictionary["12. SLR Connectivity Matrix"][g] = {}
                    mydictionary["12. SLR Connectivity Matrix"][g]["From\to"] = from_to
                    mydictionary["12. SLR Connectivity Matrix"][g]["SLR2"] = slr2
                    mydictionary["12. SLR Connectivity Matrix"][g]["SLR1"] = slr1
                    mydictionary["12. SLR Connectivity Matrix"][g]["SLR0"] = slr0
                    line = fp.readline() 
            elif re.search("13. SLR CLB Logic and Dedicated Block Utilization", line):
                
                for x in range(0 , 6):
                    line = fp.readline()
                for g in range(0,21):
                    temp = line
                    temp = temp.split("|")
                    site_type = temp[1].strip()
                    slr0 = temp[2].strip()
                    slr1 = temp[3].strip()
                    slr2 = temp[4].strip()
                    slr0percent = temp[5].strip()
                    slr1percent = temp[6].strip()
                    slr2percent = temp[7].strip()
                    if slr0 != '':
                        int(slr0)
                    if slr1 != '':
                        int(slr1)
                    if slr2 != '':
                        int(slr2)
                    if slr0percent != '':
                        float(slr0percent)
                    if slr1percent != '':
                        float(slr1percent)
                    if slr2percent != '':
                        float(slr2percent)
                    mydictionary["13. SLR CLB Logic and Dedicated Block Utilization"][g] = {}
                    mydictionary["13. SLR CLB Logic and Dedicated Block Utilization"][g]["Site type"] = from_to
                    mydictionary["13. SLR CLB Logic and Dedicated Block Utilization"][g]["SLR0"] = slr0
                    mydictionary["13. SLR CLB Logic and Dedicated Block Utilization"][g]["SLR1"] = slr1
                    mydictionary["13. SLR CLB Logic and Dedicated Block Utilization"][g]["SLR2"] = slr2
                    mydictionary["13. SLR CLB Logic and Dedicated Block Utilization"][g]["SLR0%"] = slr0percent
                    mydictionary["13. SLR CLB Logic and Dedicated Block Utilization"][g]["SLR1%"] = slr1percent
                    mydictionary["13. SLR CLB Logic and Dedicated Block Utilization"][g]["SLR2%"] = slr1percent
                    line = fp.readline()
                
            elif re.search("14. SLR IO Utilization", line):
                
                for x in range(0 , 6):
                    line = fp.readline()
                for g in range(0,4):
                    temp = line
                    temp = temp.split("|")
                    SLR_index = temp[1].strip()
                    used_IOB = temp[2].strip()
                    percent_IOB = temp[3].strip()
                    used_ipads = temp[4].strip()
                    percent_ipads = temp[5].strip()
                    used_opads = temp[6].strip()
                    percent_opads = temp[7].strip()
                    gts = temp[8].strip()
                    if used_IOB != '':
                        int(used_IOB)
                    if percent_IOB != '':
                        float(percent_IOB)
                    if used_ipads != '':
                        int(used_ipads)
                    if percent_ipads != '':
                        float(percent_ipads)
                    if used_opads != '':
                        int(used_opads)
                    if percent_opads != '':
                        float(percent_opads)
                    if gts != '':
                        int(gts)
                    mydictionary["14. SLR IO Utilization"][g] = {}
                    mydictionary["14. SLR IO Utilization"][g]["SLR Index"] = SLR_index
                    mydictionary["14. SLR IO Utilization"][g]["used IOBs"] = used_IOB
                    mydictionary["14. SLR IO Utilization"][g]["(%)IOBs"] = percent_IOB
                    mydictionary["14. SLR IO Utilization"][g]["used ipads"] = used_ipads
                    mydictionary["14. SLR IO Utilization"][g]["(%)IPADs"] = percent_ipads
                    mydictionary["14. SLR IO Utilization"][g]["Used OPADs"] = used_opads
                    mydictionary["14. SLR IO Utilization"][g]["(%)OPADs"] = percent_opads
                    mydictionary["14. SLR IO Utilization"][g]["(GTs"] = gts
                    
                    if(g == 2):
                        line = fp.readline()
                    line = fp.readline()
            line = fp.readline()
    return mydictionary

# %%
daction = parsefile('n64R8.rpt')
diction = parsefile('n32R8.rpt')
